# %% [markdown]
# Student: Lucienne Kuzmanovska (Section 005)
# Modeling the Perfect Player: Men’s FIFA Recruitment Strategies
# Oral Presentation: Awesome
# Slides: Excellent
# ? = Did Stats like points scored/stopped correlate with any of your other data?
# Content: Wages, Ages, and Teams, Nationality  - Correlation - lots of pretty graphs - CAPS,
# Comments : loved the silliness of making the focus about sports betting.
#
#
# Student: Lakshya Goel
# Title:  mortality rates
# Oral Presentation: Dev
# Slides - Dev-
#  lots of data
# ? ARIMA models sound interesting and would love to learn more - where can I use them
# Content: Exc
# India, China, and America , ARIMA - regression models , AutoRegressive Integrated Moving Average  , India much higher general mortality rate, all rates decreasing over time, GDP and and Mortality Rates
# Comments: Not just modeling the trend but maybe including stats that have been affecting this trend
# ARIMA models sound interesting and would love to learn more
#
# Student Name: Jonah Timm-Blow
# Project Title: PGA Tour Statistical Analysis
# Oral Presentation: Dev- read from slides
# Slides: Dev
# Content: Great
# Strokes Gained - Approach > Putting > Driving > Around the green
# My Question: How do different hole lengths directly affect the stats and what do the average stroke stats look like
# Additional Comments:  More insightful commentary into the project
#
# Student Name: Julianna Christenson
# Project Title: Midwest COVID Trends
# Oral Presentation: Good
# Slides: Excellent
# Content: Good
# Where was Covid most prevalent - gender, state, age, vaccines Correlation between vaccines and admissions IL IN MI MN MO OH WI Ohio has the most covid 65+ most admitted  MI most vaxed Very high  inverse correlation between vaccination rate and cases
# My Question: How were different levels of advertising effective in vaccine rate
# Additional Comments: I liked learning about the personal factor of this and seeming how dominant the correlations were
#
#
# Student Name: Gurnate Singh
# Project Title: Impact of External Obligations on Students’ Academic Success and Well-being
# Oral Presentation: Dev
# Slides: Great
# Content: Exc
# My Question: What were the direct measures of academic performance? Tests? GPA?
# Additional Comments: Self Esteem and Academic Performance -  big positive correlation
# Extracurricular Activities and stress - correlated - can reduce stress???? - some language unclear
#
# Student Name: Emmanuel Luk
# Project Title: E Commerce market
# Oral Presentation: Great
# Slides: Great
# Content: Dev
# My Question: What were some other statistics of the buyers and sellers on the platform and how was the amount of advertising correlated with sales or how did supply demand affect it?
# Additional Comments:  ecommerce trends
# What is the best niche to target when starting a brand
# Casual and fashion niche
# Niche, sales, and price used to calculate what would be the most profitable
# Electronics > Home and Health > Beauty
#
# Student Name: Heather Sponaugle
# Project Title: Climate Change
# Oral Presentation: Great
# Slides: Great
# Content: Dev
# My Question: How was she able to fill the empty values - how might I be able to do this
# Additional Comments: Awesome that she was able to properly display the data even with so many missing columns I thought that was really cool, but it left some big gaps in data, and the final result wasn’t what I expected or what the other data was inferring How has climate change affected the health of coral reefs
# Percent bleaching by year - smart solutions to lots of zeros and empty value in data
# Global Average temperature change - ‘Temperature anomaly’
# Spikes in temperature correlate with spike in bleaching
#
#
#
#
#
#
#
#
#
#
#
# Student Name: Laura Santos de Silva
# Project Title: Countries in the world that are dying
# Oral Presentation: Dev
# Slides: Exc
# Content: Exc
# My Question: This project had so much data I loved it - a lil past time but thats okay - would have loved to hear more about GDP correlations
# Additional Comments: I thought it was hilarious that the country that’s within a city (the Vatican, Holy See) was the most declining  Cultural presentation
# Population - Fertility rates - population number - median age
# Immigration - Yearly change, migrants
# Cool flowchart
#
#
# Student Name: Kylee Socacz
# Project Title: Cases of diseases in California correlation
# Oral Presentation: Great
# Slides: Good
# Content: Good
# My Question: what do other diseases like STI’s have to correlate
# Additional Comments: Liked the shift in data from totals to percentiles and learned a lot more from it
#
#
# Student Name: Himanshu Janmeda
# Project Title: Polynomial Regression model based upon house features
# Oral Presentation: Great
# Slides: Good
# Content: Exc
# My Question: how can we define some of these statistics to make more sense and be understood
# Additional Comments: kaggle Sale price - overall quality - GRLivAREa - Garage Size, 1stFloor Sqft, Basement Sqft - Corr Matrix
# RMSE - second degree polynomials found to work the best
# Model has
#
#
#
#
#
# Student Name: Benjamin Navan
# Project Title: Habitable planets
# Oral Presentation: Good
# Slides: Great
# Content: Dev
# My Question:
# Additional Comments: A lot of  abstract data - would have liked to look at things with some more solid dataDrake’s Equation - Fermi’s paradox - civilizations living or dying
# Hypothetical and theoretical variables getting dropped
# Finding habitable planets and using data to get the definition for a habitable planet
# Optimism of variables (bigger) result in larger number of habitable planets
# Distance from star, planet mass important in determining habitable or not
#
#
# Student Name: Tayden Cuasay
# Project Title: Tesla and Electric Vehicles - Better Option?
# Oral Presentation: Great
# Slides: Great
# Content: Great
# My Question: What was the scoring system and how were you able to correlate data in such different areas
# Additional Comments: What are best models - how do costs affect the performance
# Model and performance
# Dual motor vs not are important factors in price and correlate strongly with acceleration and speed
# Tesla Model Y scores better than other EVS
#
#
# Student Name: Isha Patel
#
#
# Project Title: BEYONCE
# Oral Presentation: Exc
# Slides: Great
# Content: Exc
# My Question: I would love to know how she formatted her graphs as ‘spreads’ and would like to see ‘trends’ in her other stats and would like to know about other artists
# Additional Comments: I loved every bit of this Danceability, valence, energy, loudness, acousticness, instrumentalness, liveness, speechiness, tempo
# Energy - experimental and variable
#
#
# Student Name: Kaylee Chang
# Project Title: Correlation of Suicide rate and economic values
# Oral Presentation: Dev
# Slides: Dev
# Content: Good
# My Question: I loved so much of this but I would like to know a lot more about correlation data and what her stats meant
# Additional Comments: 2000-2019 - not include covid results because skewing
# So much personality i love this girl
# GDP, Gini, Unemployment, Suicide Rate
# GDP trend, Gini trend
#
#
# Student Name:
# Project Title: MLS
# Oral Presentation: Exc
# Slides: Exc
# Content: Exc
# My Question: How are stats and payments and viewership correlating
# Additional Comments: Homefield advantage, stats, rule changes
# Shots increase - yellows increase, reds decrease FOR HOME TEAMS
#
#
# Student Name: Audrey Duthler
# Project Title: Mortality Causes
# Oral Presentation: Dev
# Slides: Great
# Content: Dev
# My Question: Would love to see a lot more data
# Additional Comments: What will the mortality rate be in the next 5 years due to natural causes
# Natural cause decreasing,
# Alzheimers increasing
# Septicemia increasing
# Flu and pneumonia - slightly decreasing
#
#
#
#
#
#
#
#
# Student Name: Landon Sykes
# Project Title: Critical Thinking and Education
# Oral Presentation: Great
# Slides: Good
# Content: Okay
# My Question: How can IQ Tests and grades and other measurements be affected by these stats or other puzzles and video game performance and other things like that
# Additional Comments: Quality of education have impact on complex puzzle and problem solving skills
# Puzzle solving ability - high level or correlation with quality of education
